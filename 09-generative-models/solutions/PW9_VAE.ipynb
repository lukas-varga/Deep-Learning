# %% [markdown]
# # PW9: Variational Autoencoder
#
# Objective: Generate images using a Variational AutoEncoder and analyze the latent space

# %%
import tensorflow.keras as tk
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

from tensorflow.keras.layers import Input, Dense, Lambda, Flatten, Reshape, Conv2D, Conv2DTranspose,BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import metrics

# %% [markdown]
# # Data
# [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) is a dataset containing 70 000 28$\times$ 28 gray level images from 10 categories  (	T-shirt/top, Trouser, Pullover, Dress, Coat, Sandal, Shirt, Sneaker, Bag, Ankle boot) from Zalando articles. 60 000 images compose the training set, and the 10 000 remaining ones are for testing.

# %%
(x_train, y_train), (x_test, y_test) = tk.datasets.fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

labels = {0: "T-shirt", 1: "Trousers", 2: "Pull", 3: "Dress", 4: "Coat", 
          5: "Sandal", 6: "Shirt", 7: "Sneaker", 8: "Bag", 9: "Ankle boot"}
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
plt.figure(figsize=(16, 8))
for i in range(0, 10):
    plt.subplot(2, 5, i + 1)
    plt.title(labels[y_train[i]])
    plt.imshow(x_train[i], cmap="gray")
    plt.axis("off")
plt.show()

# %% [markdown]
# # Models
# Two models are developed in the following:
# - A very basic one where the encoder and the decoder are MLPs
# - A second one based on CNNs

# %% [markdown]
# ## MLP-based VAE

# %% [markdown]
# ### Reshaping the data

# %%
x_train_MLP = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test_MLP = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# %% [markdown]
# ### Encoder definition
# The encoder is a MLP composed of 1 hidden layer with size `hidden_dim` and ReLU activation, followed by two parallel output layers of size `latent_dim`, modeling the mean and the variance of the distribution in the latent space.

# %%
dim = 784
latent_dim = 10
hidden_dim = 256


def Encoder(dim, hidden_dim, latent_dim):
    x = Input(shape=(dim,))
    hidden = Dense(hidden_dim, activation='relu')(x)
    z_mean = Dense(latent_dim)(hidden)
    z_log_var = Dense(latent_dim)(hidden)
    return Model(inputs=x, outputs=[z_mean, z_log_var],name="Encoder_MLP")
    
encoder = Encoder(dim, hidden_dim, latent_dim)

# %% [markdown]
# ### Latent space
#
# Let $z$ be a random variable $ z \sim \mathcal{N}(\mu_z(x), \sigma_z(x)) $ conditioned to the input $x$.
#
# We use the reparametrization trick in order to allow efficient backpropagation $ z = \mu_z(x) + \sigma_z(x) \cdot \epsilon$, where  $ \epsilon \sim \mathcal{N}(0, 1) $
#
# The output of the encoder parametrizes $log(\sigma^2_z(x))$ instead of   $\sigma_z(x)$ (ensures the positivity of the variance) $\sigma^2_z(x)$.

# %%
def sample(inputs):
    z_mean, z_log_var = inputs
    batch_size = K.shape(z_mean)[0]
    epsilon = K.random_normal(shape=(batch_size, latent_dim),mean=0., stddev=1.)
    return z_mean + K.exp(z_log_var / 2) * epsilon

sampling_layer = Lambda(sample, output_shape=(latent_dim,),name="latent")

# %% [markdown]
# ### Decoder
# The decoder start from the latent space, then includes a layer with `hidden_dim` units and ReLU activation, and output a layer of size (dim(x)) with sigmoïd activation.

# %%
def Decoder(latent_dim, hidden_dim, dim):
    decoder_input = Input(shape=(latent_dim,))
    x = Dense(hidden_dim, activation='relu')(decoder_input)
    x = Dense(dim, activation='sigmoid')(x)
    return Model(decoder_input, x, name="Decoder_MLP")

decoder = Decoder(latent_dim, hidden_dim, dim)

# %% [markdown]
# To illustrate: give the decoder a random latent vector to see the output (weights and biases of the decoder are not trained yet)

# %%
z_alea = np.random.normal(loc=0, scale=1, size=(1, latent_dim))
generated = decoder.predict(z_alea)
plt.imshow(generated.reshape(28, 28), cmap=plt.cm.gray)
plt.axis('off');

# %% [markdown]
# ### VAE
# From the previous MLP, build the VAE :
# - Encoder
# - Sampling layer, drawing mean and variance
# - Decoder
#
# We provide the computation of the loss function, as well as the definition of the optimizer

# %%
def VAE(input_shape, encoder, decoder, sampling_layer,beta):

    x = Input(shape=input_shape, name="input")
    z_mean, z_log_var = encoder(x)
    z = sampling_layer([z_mean, z_log_var])
    x_decoded_mean = decoder(z)
    vae = Model(x, x_decoded_mean)

    # Loss function : Evidence Lower Bound (ELBO)
    xent_loss = dim * metrics.binary_crossentropy(K.flatten(x), K.flatten(x_decoded_mean))
    kl_loss = - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
    vae_loss = K.mean(xent_loss + beta*kl_loss)

    vae.add_loss(vae_loss)
    vae.compile(optimizer='adam')
    return vae

vae = VAE((dim,), encoder, decoder,sampling_layer=sampling_layer,beta=1)

# %% [markdown]
# Train the VAE and save the weights for further use (with the [save_weights](https://keras.io/api/models/model_saving_apis/) function)

# %%
#Once trained, can comment the two next lines
vae.fit(x_train_MLP, epochs=100, batch_size=100,validation_data=(x_test_MLP, None))
vae.save_weights("VAE_classic_weights.h5")
vae.load_weights("VAE_classic_weights.h5")
# Out:
# Epoch 1/100
# 600/600 [==============================] - 4s 5ms/step - loss: 324.1771 - val_loss: 259.7111
# Epoch 2/100
# 600/600 [==============================] - 2s 4ms/step - loss: 256.0792 - val_loss: 253.4075
# Epoch 3/100
# 600/600 [==============================] - 2s 4ms/step - loss: 251.1584 - val_loss: 250.7700
# Epoch 4/100
# 600/600 [==============================] - 2s 4ms/step - loss: 248.9574 - val_loss: 249.2090
# Epoch 5/100
# 600/600 [==============================] - 2s 4ms/step - loss: 246.9832 - val_loss: 248.1927
# Epoch 6/100
# 600/600 [==============================] - 2s 4ms/step - loss: 246.5183 - val_loss: 246.9305
# Epoch 7/100
# 600/600 [==============================] - 2s 4ms/step - loss: 245.4202 - val_loss: 246.2836
# Epoch 8/100
# 600/600 [==============================] - 2s 4ms/step - loss: 244.8938 - val_loss: 245.9727
# Epoch 9/100
# 600/600 [==============================] - 2s 4ms/step - loss: 243.7313 - val_loss: 245.6513
# Epoch 10/100
# 600/600 [==============================] - 2s 4ms/step - loss: 243.7504 - val_loss: 244.9012
# Epoch 11/100
# 600/600 [==============================] - 2s 4ms/step - loss: 242.4185 - val_loss: 245.0017
# Epoch 12/100
# 600/600 [==============================] - 2s 4ms/step - loss: 242.5815 - val_loss: 244.3311
# Epoch 13/100
# 600/600 [==============================] - 2s 4ms/step - loss: 242.1866 - val_loss: 244.1629
# Epoch 14/100
# 600/600 [==============================] - 2s 4ms/step - loss: 241.9858 - val_loss: 244.0063
# Epoch 15/100
# 600/600 [==============================] - 2s 4ms/step - loss: 241.8640 - val_loss: 243.8530
# Epoch 16/100
# 600/600 [==============================] - 2s 4ms/step - loss: 242.1011 - val_loss: 243.5882
# Epoch 17/100
# 600/600 [==============================] - 2s 4ms/step - loss: 241.6329 - val_loss: 243.2772
# Epoch 18/100
# 600/600 [==============================] - 2s 4ms/step - loss: 240.9331 - val_loss: 243.3227
# Epoch 19/100
# 600/600 [==============================] - 2s 4ms/step - loss: 240.9905 - val_loss: 242.8687
# Epoch 20/100
# 600/600 [==============================] - 2s 4ms/step - loss: 241.1703 - val_loss: 243.1802
# Epoch 21/100
# 600/600 [==============================] - 2s 4ms/step - loss: 241.3892 - val_loss: 243.1119
# Epoch 22/100
# 600/600 [==============================] - 2s 4ms/step - loss: 240.2128 - val_loss: 242.8473
# Epoch 23/100
# 600/600 [==============================] - 2s 4ms/step - loss: 240.7426 - val_loss: 242.5604
# Epoch 24/100
# 600/600 [==============================] - 2s 4ms/step - loss: 240.4046 - val_loss: 242.4602
# Epoch 25/100
# 600/600 [==============================] - 2s 4ms/step - loss: 240.9061 - val_loss: 242.3337
# Epoch 26/100
# 600/600 [==============================] - 2s 4ms/step - loss: 240.8535 - val_loss: 242.6349
# Epoch 27/100
# 600/600 [==============================] - 2s 4ms/step - loss: 240.9247 - val_loss: 242.2863
# Epoch 28/100
# 600/600 [==============================] - 2s 4ms/step - loss: 240.3162 - val_loss: 242.5365
# Epoch 29/100
# 600/600 [==============================] - 2s 4ms/step - loss: 240.3248 - val_loss: 242.1469
# Epoch 30/100
# 600/600 [==============================] - 2s 4ms/step - loss: 240.2413 - val_loss: 241.9026
# Epoch 31/100
# 600/600 [==============================] - 2s 4ms/step - loss: 240.3516 - val_loss: 242.0500
# Epoch 32/100
# 600/600 [==============================] - 2s 4ms/step - loss: 240.3548 - val_loss: 241.9196
# Epoch 33/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.8052 - val_loss: 242.0406
# Epoch 34/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.2671 - val_loss: 241.8895
# Epoch 35/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.7445 - val_loss: 241.6473
# Epoch 36/100
# 600/600 [==============================] - 2s 4ms/step - loss: 240.2376 - val_loss: 241.6519
# Epoch 37/100
# 600/600 [==============================] - 2s 4ms/step - loss: 240.1859 - val_loss: 241.5777
# Epoch 38/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.5149 - val_loss: 241.6292
# Epoch 39/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.0880 - val_loss: 241.7802
# Epoch 40/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.5205 - val_loss: 241.4793
# Epoch 41/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.8377 - val_loss: 241.4822
# Epoch 42/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.8563 - val_loss: 241.4590
# Epoch 43/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.4832 - val_loss: 241.3208
# Epoch 44/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.3135 - val_loss: 241.5394
# Epoch 45/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.1810 - val_loss: 241.4476
# Epoch 46/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.7654 - val_loss: 241.3959
# Epoch 47/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.6898 - val_loss: 241.2917
# Epoch 48/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.5580 - val_loss: 241.2816
# Epoch 49/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.3336 - val_loss: 241.4668
# Epoch 50/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.5565 - val_loss: 241.1503
# Epoch 51/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.3775 - val_loss: 241.3985
# Epoch 52/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.9485 - val_loss: 241.4608
# Epoch 53/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.0529 - val_loss: 241.3060
# Epoch 54/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.8275 - val_loss: 241.2774
# Epoch 55/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.0461 - val_loss: 241.0220
# Epoch 56/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.6819 - val_loss: 241.6006
# Epoch 57/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.1296 - val_loss: 241.0206
# Epoch 58/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.6820 - val_loss: 241.1300
# Epoch 59/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.6138 - val_loss: 241.0524
# Epoch 60/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.4227 - val_loss: 241.0764
# Epoch 61/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.8131 - val_loss: 241.0389
# Epoch 62/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.0482 - val_loss: 241.0462
# Epoch 63/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.9122 - val_loss: 240.9597
# Epoch 64/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.7677 - val_loss: 241.1373
# Epoch 65/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.2138 - val_loss: 240.9842
# Epoch 66/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.4282 - val_loss: 240.8589
# Epoch 67/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.1135 - val_loss: 241.1693
# Epoch 68/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.0342 - val_loss: 241.0327
# Epoch 69/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.2859 - val_loss: 240.9555
# Epoch 70/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.8956 - val_loss: 240.9163
# Epoch 71/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.9453 - val_loss: 240.9917
# Epoch 72/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.6941 - val_loss: 241.0064
# Epoch 73/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.3574 - val_loss: 240.8926
# Epoch 74/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.9118 - val_loss: 241.0331
# Epoch 75/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.7063 - val_loss: 240.6729
# Epoch 76/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.6685 - val_loss: 240.7987
# Epoch 77/100
# 600/600 [==============================] - 2s 4ms/step - loss: 239.2271 - val_loss: 240.9834
# Epoch 78/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.6522 - val_loss: 240.9239
# Epoch 79/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.0912 - val_loss: 240.8568
# Epoch 80/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.6823 - val_loss: 240.8469
# Epoch 81/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.8178 - val_loss: 240.7448
# Epoch 82/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.6721 - val_loss: 240.8194
# Epoch 83/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.2599 - val_loss: 240.7031
# Epoch 84/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.6998 - val_loss: 240.7533
# Epoch 85/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.5416 - val_loss: 240.7853
# Epoch 86/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.4250 - val_loss: 240.6723
# Epoch 87/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.6569 - val_loss: 240.7167
# Epoch 88/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.4597 - val_loss: 240.6287
# Epoch 89/100
# 600/600 [==============================] - 2s 4ms/step - loss: 237.9806 - val_loss: 240.6450
# Epoch 90/100
# 600/600 [==============================] - 3s 5ms/step - loss: 238.7650 - val_loss: 240.7809
# Epoch 91/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.3861 - val_loss: 240.6562
# Epoch 92/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.0330 - val_loss: 240.6694
# Epoch 93/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.3462 - val_loss: 240.6982
# Epoch 94/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.0959 - val_loss: 240.4329
# Epoch 95/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.3677 - val_loss: 240.7750
# Epoch 96/100
# 600/600 [==============================] - 2s 4ms/step - loss: 237.9190 - val_loss: 240.6981
# Epoch 97/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.5857 - val_loss: 240.6118
# Epoch 98/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.1383 - val_loss: 240.7442
# Epoch 99/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.2499 - val_loss: 240.7488
# Epoch 100/100
# 600/600 [==============================] - 2s 4ms/step - loss: 238.1826 - val_loss: 240.6385

# %% [markdown]
# Now that the VAE is trained, use the decoder to generate an image, from a latent vector.

# %%
z_alea = np.random.normal(size=(1, latent_dim))
generated = decoder.predict(z_alea)
plt.imshow(generated.reshape(28, 28), cmap=plt.cm.gray)
plt.axis('off');

# %% [markdown]
# Use the model on the test set to display real and reconstructed images

# %%
x_test_decoded_vae = vae.predict(x_test_MLP, batch_size= 100)

n = 10  
plt.figure(figsize=(15, 4))
for i in range(n):
    ax = plt.subplot(3, n, i + 1)
    plt.title('Test Image')
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    

    ax = plt.subplot(3, n, i + 1 + n)
    plt.title('VAE')
    plt.imshow(x_test_decoded_vae[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.tight_layout()

# %% [markdown]
# ### Understanding the latent space
#
# if `latent_dim`is set to 2, we can use te encoder to project the images onto a plane. And if we color-code the 2D point with its class, we can visualize the distribution of the classes in the latent space.

# %%
latent_dim = 2
encoder = Encoder(dim, hidden_dim, latent_dim)
sampling_layer = Lambda(sample, output_shape=(latent_dim,),name="Sampler_latent")
decoder = Decoder(latent_dim, hidden_dim, dim)
# Beta VAE
bet = 10
vae = VAE((dim,), encoder, decoder,sampling_layer=sampling_layer,beta=10)

#Once trained, can comment the two next lines
vae.fit(x_train_MLP, epochs=100, batch_size=100,validation_data=(x_test_MLP, None))
vae.save_weights("VAE_classic_weights_2D.h5")
vae.load_weights("VAE_classic_weights_2D.h5")
# Out:
# Epoch 1/100
# 600/600 [==============================] - 3s 4ms/step - loss: 385.6150 - val_loss: 319.5822
# Epoch 2/100
# 600/600 [==============================] - 2s 4ms/step - loss: 316.0501 - val_loss: 314.4339
# Epoch 3/100
# 600/600 [==============================] - 2s 4ms/step - loss: 311.5665 - val_loss: 311.6089
# Epoch 4/100
# 600/600 [==============================] - 2s 4ms/step - loss: 309.8759 - val_loss: 309.8595
# Epoch 5/100
# 600/600 [==============================] - 2s 4ms/step - loss: 309.0601 - val_loss: 309.1943
# Epoch 6/100
# 600/600 [==============================] - 2s 4ms/step - loss: 307.3782 - val_loss: 309.0210
# Epoch 7/100
# 600/600 [==============================] - 2s 4ms/step - loss: 307.2048 - val_loss: 307.6099
# Epoch 8/100
# 600/600 [==============================] - 2s 4ms/step - loss: 305.7577 - val_loss: 306.9292
# Epoch 9/100
# 600/600 [==============================] - 2s 4ms/step - loss: 306.0329 - val_loss: 306.3792
# Epoch 10/100
# 600/600 [==============================] - 2s 4ms/step - loss: 305.6093 - val_loss: 305.8083
# Epoch 11/100
# 600/600 [==============================] - 2s 4ms/step - loss: 304.3811 - val_loss: 305.3588
# Epoch 12/100
# 600/600 [==============================] - 2s 4ms/step - loss: 303.9433 - val_loss: 304.6159
# Epoch 13/100
# 600/600 [==============================] - 2s 4ms/step - loss: 303.5783 - val_loss: 304.9066
# Epoch 14/100
# 600/600 [==============================] - 2s 4ms/step - loss: 303.4901 - val_loss: 304.0770
# Epoch 15/100
# 600/600 [==============================] - 2s 4ms/step - loss: 303.5354 - val_loss: 304.0484
# Epoch 16/100
# 600/600 [==============================] - 2s 4ms/step - loss: 302.7103 - val_loss: 303.8929
# Epoch 17/100
# 600/600 [==============================] - 3s 4ms/step - loss: 302.9141 - val_loss: 303.7257
# Epoch 18/100
# 600/600 [==============================] - 2s 4ms/step - loss: 301.9064 - val_loss: 304.1158
# Epoch 19/100
# 600/600 [==============================] - 2s 4ms/step - loss: 302.3327 - val_loss: 303.3204
# Epoch 20/100
# 600/600 [==============================] - 2s 4ms/step - loss: 301.9527 - val_loss: 303.3319
# Epoch 21/100
# 600/600 [==============================] - 2s 4ms/step - loss: 302.1991 - val_loss: 303.6293
# Epoch 22/100
# 600/600 [==============================] - 2s 4ms/step - loss: 301.5580 - val_loss: 303.4180
# Epoch 23/100
# 600/600 [==============================] - 2s 4ms/step - loss: 301.9350 - val_loss: 303.3107
# Epoch 24/100
# 600/600 [==============================] - 2s 4ms/step - loss: 301.1184 - val_loss: 303.4241
# Epoch 25/100
# 600/600 [==============================] - 2s 4ms/step - loss: 301.4015 - val_loss: 302.9308
# Epoch 26/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.9982 - val_loss: 303.2441
# Epoch 27/100
# 600/600 [==============================] - 2s 4ms/step - loss: 301.1536 - val_loss: 302.8345
# Epoch 28/100
# 600/600 [==============================] - 2s 4ms/step - loss: 301.3052 - val_loss: 302.3066
# Epoch 29/100
# 600/600 [==============================] - 2s 4ms/step - loss: 301.4307 - val_loss: 302.3226
# Epoch 30/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.6384 - val_loss: 302.4124
# Epoch 31/100
# 600/600 [==============================] - 2s 4ms/step - loss: 301.0402 - val_loss: 302.2752
# Epoch 32/100
# 600/600 [==============================] - 2s 4ms/step - loss: 301.2927 - val_loss: 302.1953
# Epoch 33/100
# 600/600 [==============================] - 2s 4ms/step - loss: 301.1205 - val_loss: 302.4255
# Epoch 34/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.6196 - val_loss: 301.8318
# Epoch 35/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.5699 - val_loss: 302.7952
# Epoch 36/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.1077 - val_loss: 302.0724
# Epoch 37/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.5211 - val_loss: 302.4831
# Epoch 38/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.5874 - val_loss: 302.4241
# Epoch 39/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.6312 - val_loss: 302.1560
# Epoch 40/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.2209 - val_loss: 302.1605
# Epoch 41/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.6572 - val_loss: 301.7365
# Epoch 42/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.5020 - val_loss: 301.7591
# Epoch 43/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.8902 - val_loss: 302.2397
# Epoch 44/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.8091 - val_loss: 301.6619
# Epoch 45/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.6503 - val_loss: 302.0363
# Epoch 46/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.1047 - val_loss: 301.7467
# Epoch 47/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.4460 - val_loss: 301.7661
# Epoch 48/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.5138 - val_loss: 301.6917
# Epoch 49/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.1750 - val_loss: 301.5957
# Epoch 50/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.3948 - val_loss: 301.3439
# Epoch 51/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.5398 - val_loss: 301.5274
# Epoch 52/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.8781 - val_loss: 301.5440
# Epoch 53/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.7853 - val_loss: 301.6194
# Epoch 54/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.3509 - val_loss: 302.1757
# Epoch 55/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.4075 - val_loss: 301.4110
# Epoch 56/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.7685 - val_loss: 301.3707
# Epoch 57/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.0389 - val_loss: 301.7400
# Epoch 58/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.6788 - val_loss: 301.3365
# Epoch 59/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.2474 - val_loss: 302.0764
# Epoch 60/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.3232 - val_loss: 301.7904
# Epoch 61/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.3145 - val_loss: 301.1169
# Epoch 62/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.4035 - val_loss: 301.5534
# Epoch 63/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.2534 - val_loss: 301.0568
# Epoch 64/100
# 600/600 [==============================] - 3s 4ms/step - loss: 299.7546 - val_loss: 301.2992
# Epoch 65/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.7982 - val_loss: 301.2302
# Epoch 66/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.9095 - val_loss: 301.2182
# Epoch 67/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.8397 - val_loss: 301.2233
# Epoch 68/100
# 600/600 [==============================] - 3s 4ms/step - loss: 299.1848 - val_loss: 301.1740
# Epoch 69/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.6885 - val_loss: 301.3224
# Epoch 70/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.9230 - val_loss: 301.3726
# Epoch 71/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.6197 - val_loss: 301.3092
# Epoch 72/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.2746 - val_loss: 301.6144
# Epoch 73/100
# 600/600 [==============================] - 2s 4ms/step - loss: 298.8717 - val_loss: 301.1324
# Epoch 74/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.6376 - val_loss: 300.9936
# Epoch 75/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.8945 - val_loss: 301.5523
# Epoch 76/100
# 600/600 [==============================] - 2s 4ms/step - loss: 300.6519 - val_loss: 301.0920
# Epoch 77/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.5777 - val_loss: 301.3541
# Epoch 78/100
# 600/600 [==============================] - 2s 4ms/step - loss: 298.8876 - val_loss: 300.9274
# Epoch 79/100
# 600/600 [==============================] - 2s 4ms/step - loss: 298.8722 - val_loss: 301.4190
# Epoch 80/100
# 600/600 [==============================] - 3s 4ms/step - loss: 299.1953 - val_loss: 301.6053
# Epoch 81/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.1008 - val_loss: 300.8332
# Epoch 82/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.1690 - val_loss: 300.7867
# Epoch 83/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.5513 - val_loss: 301.2657
# Epoch 84/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.0675 - val_loss: 300.9873
# Epoch 85/100
# 600/600 [==============================] - 2s 4ms/step - loss: 298.6586 - val_loss: 300.8824
# Epoch 86/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.4392 - val_loss: 300.7382
# Epoch 87/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.2369 - val_loss: 300.9486
# Epoch 88/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.2046 - val_loss: 301.1750
# Epoch 89/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.5251 - val_loss: 301.1731
# Epoch 90/100
# 600/600 [==============================] - 3s 4ms/step - loss: 299.3595 - val_loss: 300.6663
# Epoch 91/100
# 600/600 [==============================] - 3s 4ms/step - loss: 298.7981 - val_loss: 301.0633
# Epoch 92/100
# 600/600 [==============================] - 3s 4ms/step - loss: 299.2512 - val_loss: 300.7977
# Epoch 93/100
# 600/600 [==============================] - 3s 4ms/step - loss: 299.2659 - val_loss: 301.3166
# Epoch 94/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.0028 - val_loss: 300.7784
# Epoch 95/100
# 600/600 [==============================] - 3s 4ms/step - loss: 298.7687 - val_loss: 301.2552
# Epoch 96/100
# 600/600 [==============================] - 3s 4ms/step - loss: 298.7346 - val_loss: 301.1201
# Epoch 97/100
# 600/600 [==============================] - 3s 4ms/step - loss: 298.9017 - val_loss: 300.7141
# Epoch 98/100
# 600/600 [==============================] - 3s 4ms/step - loss: 299.1397 - val_loss: 301.3324
# Epoch 99/100
# 600/600 [==============================] - 2s 4ms/step - loss: 299.3904 - val_loss: 301.2120
# Epoch 100/100
# 600/600 [==============================] - 2s 4ms/step - loss: 298.6740 - val_loss: 300.7102

# %%
x_test_encoded, x_test_encoded_log_var = encoder.predict(x_test_MLP, batch_size=100)
plt.figure(figsize=(10, 6))
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test,cmap=plt.cm.tab10)
cb = plt.colorbar()
cb.set_ticks(list(labels.keys()))
cb.set_ticklabels(list(labels.values()))
cb.update_ticks()
plt.show()
plt.tight_layout()

# %% [markdown]
# Sandal, Sneaker and Ankle boots form a separate cluster.
# T-shirt, Coat and Shirt are also very intricated.

# %% [markdown]
# The unit square can be tranformed using the inverse conditional distribution of the Gaussian to visualize the latent space and the manifold on which the examples lie

# %%
n = 20  
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
grid_x = norm.ppf(np.linspace(0.05, 0.95, n))
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.axis('off')
plt.tight_layout()

# %% [markdown]
# ## CNN-based VAE

# %% [markdown]
# Prepare data

# %%
x_train_CNN = np.expand_dims(x_train, -1)
x_test_CNN = np.expand_dims(x_test, -1)

# %% [markdown]
# ### Encoder

# %% [markdown]
# Build the following encoder
# - Input layer
# - [Convolution](https://keras.io/layers/convolutional/) layer, `filters` filters of size `kernel_size`,  ReLU activation
# - [Normalisation](https://keras.io/layers/normalization/) layer
# - [Convolution](https://keras.io/layers/convolutional/) layer, `filters` filters of size  `kernel_size`, ReLU activation and (2,2) strides
# - [Normalisation](https://keras.io/layers/normalization/) layer
# - [Convolution](https://keras.io/layers/convolutional/) `filters` filters of size `kernel_size`,  ReLU activation
# - [Normalisation](https://keras.io/layers/normalization/) layer
# - [Convolution](https://keras.io/layers/convolutional/) l`filters` filters of size `kernel_size`,  ReLU activation and  (2,2) strides
# - [Flatten](https://keras.io/layers/core/) layer
# - [Dense](https://keras.io/layers/core/) layer,  ReLU activation
# - [Dense](https://keras.io/layers/core/) layer for the mean of  $z$
# - [Dense](https://keras.io/layers/core/) layer for the variance of $z$
#
# The dimensions must fit to the problem.
# `latent_dim` is set to 2 for a 2D representation. To allow a better image generation, it must be increased (but no 2D representation is possible if >3)

# %%
img_rows, img_cols, img_chns = 28, 28, 1
filters = 32
kernel_size = 3
hidden_dim = 128

latent_dim = 2

def CEncoder(img_rows, img_cols, img_chns,
                      latent_dim, hidden_dim):
    x = Input(shape=(img_rows, img_cols, img_chns))
    x_conv = Conv2D(filters,
                    kernel_size=kernel_size,
                    padding='same', activation='relu')(x)
    x_conv = BatchNormalization()(x_conv)
    x_conv = Conv2D(filters,
                    kernel_size=kernel_size,
                    padding='same', activation='relu',
                    strides=(2, 2))(x_conv)
    x_conv = BatchNormalization()(x_conv)
    x_conv = Conv2D(filters,
                    kernel_size=kernel_size,
                    padding='same', activation='relu')(x_conv)
    x_conv = BatchNormalization()(x_conv)
    x_conv = Conv2D(filters,
                    kernel_size=kernel_size,
                    padding='same', activation='relu',
                    strides=(2, 2))(x_conv)
    flat = Flatten()(x_conv)
    hidden = Dense(hidden_dim, activation='relu')(flat)
    z_mean = Dense(latent_dim)(hidden)
    z_log_var = Dense(latent_dim)(hidden)
    return Model(inputs=x, outputs=[z_mean, z_log_var],
                 name='CEncoder')


cencoder = CEncoder(img_rows, img_cols, img_chns,latent_dim, hidden_dim)

# %% [markdown]
# Same latent space

# %%
sampling_layer = Lambda(sample, output_shape=(latent_dim,),name="latent")

# %% [markdown]
# ## Decoder
#
# Here is the architecture  to reproduce, with `spatial_size`=7 and `filters`=16
# - Input layer
# - Dense layer of size `hidden_dim`,  ReLU activation
# - Dense layer of size `filters * spatial_size * spatial_size`,  ReLU activation
# - Transposed convolution layer([Conv2DTranspose](https://keras.io/layers/convolutional/filters)), `filters ` filters of size 3,  (2,2) strides,  ReLU activation
# - Normalisation layer
# - Transposed convolution layer([Conv2DTranspose](https://keras.io/layers/convolutional/filters)), `filters` filters of size 3,  (2,2) strides,  ReLU activation
# - Normalisation layer
# - Transposed convolution layer([Conv2DTranspose](https://keras.io/layers/convolutional/filters)), `filters`filters of size 3,  (2,2) strides,  ReLU activation
# - Normalisation layer
# - [Convolution](https://keras.io/layers/convolutional/) layer, 1 filters of size 2,  sigmoid activation

# %%
def CDecoder(latent_dim, hidden_dim, dim,
                      spatial_size=7, filters=16):
    decoder_input = Input(shape=(latent_dim,))
    x = Dense(hidden_dim, activation='relu')(decoder_input)
    x = Dense(filters * spatial_size * spatial_size, activation='relu')(x)
    x = Reshape((spatial_size, spatial_size, filters))(x)
    x = Conv2DTranspose(filters,kernel_size=3,padding='same',strides=(2, 2),
                        activation='relu')(x)
    x = BatchNormalization()(x)
    x = Conv2DTranspose(filters,kernel_size=3,padding='same',strides=1,
                        activation='relu')(x)
    x = BatchNormalization()(x)
    x = Conv2DTranspose(filters,kernel_size=3,strides=(2, 2),padding='valid',
                        activation='relu')(x)
    x = BatchNormalization()(x)
    x = Conv2D(1, kernel_size=2, padding='valid',activation='sigmoid')(x)
    return Model(decoder_input, x, name='CDecoder')


cdecoder = CDecoder(latent_dim, hidden_dim, dim,spatial_size=7, filters=filters)

# %% [markdown]
# Image generation, before training

# %%
generated = cdecoder.predict(np.random.normal(size=(1, latent_dim)))
plt.imshow(generated.reshape(28, 28), cmap=plt.cm.gray)
plt.axis('off');

# %% [markdown]
# Build and train the corresponding VAE

# %%
input_shape = (img_rows, img_cols, img_chns)
cvae = VAE(input_shape, cencoder, cdecoder,sampling_layer,beta=10)
cvae.summary()
#Once trained, can comment the two next lines
cvae.fit(x_train_CNN, epochs=15, batch_size=100,validation_data=(x_test_CNN, None))
cvae.save_weights("convolutional_weights.h5")
cvae.load_weights("convolutional_weights.h5")
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# CEncoder (Functional)           [(None, 2), (None, 2 229796      input[0][0]
# __________________________________________________________________________________________________
# latent (Lambda)                 (None, 2)            0           CEncoder[0][0]
#                                                                  CEncoder[0][1]
# __________________________________________________________________________________________________
# CDecoder (Functional)           (None, 28, 28, 1)    230913      latent[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLam (None, 2)            0           CEncoder[0][1]
# __________________________________________________________________________________________________
# tf.math.square_3 (TFOpLambda)   (None, 2)            0           CEncoder[0][0]
# __________________________________________________________________________________________________
# tf.reshape_6 (TFOpLambda)       (None,)              0           input[0][0]
# __________________________________________________________________________________________________
# tf.reshape_7 (TFOpLambda)       (None,)              0           CDecoder[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_6 (TFOpLambda) (None, 2)            0           tf.__operators__.add_6[0][0]
#                                                                  tf.math.square_3[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_3 (TFOpLambda)      (None, 2)            0           CEncoder[0][1]
# __________________________________________________________________________________________________
# tf.cast_3 (TFOpLambda)          (None,)              0           tf.reshape_6[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_9 (TFOpLam (None,)              0           tf.reshape_7[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_7 (TFOpLambda) (None, 2)            0           tf.math.subtract_6[0][0]
#                                                                  tf.math.exp_3[0][0]
# __________________________________________________________________________________________________
# tf.keras.backend.binary_crossen (None,)              0           tf.cast_3[0][0]
#                                                                  tf.convert_to_tensor_9[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_3 (TFOpLambd (None,)              0           tf.math.subtract_7[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_6 (TFOpLamb ()                   0           tf.keras.backend.binary_crossentr
# __________________________________________________________________________________________________
# tf.math.multiply_9 (TFOpLambda) (None,)              0           tf.math.reduce_sum_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_8 (TFOpLambda) ()                   0           tf.math.reduce_mean_6[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_10 (TFOpLambda (None,)              0           tf.math.multiply_9[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_7 (TFOpLam (None,)              0           tf.math.multiply_8[0][0]
#                                                                  tf.math.multiply_10[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_7 (TFOpLamb ()                   0           tf.__operators__.add_7[0][0]
# __________________________________________________________________________________________________
# add_loss_3 (AddLoss)            ()                   0           tf.math.reduce_mean_7[0][0]
# ==================================================================================================
# Total params: 460,709
# Trainable params: 460,325
# Non-trainable params: 384
# __________________________________________________________________________________________________
# Epoch 1/15
# 600/600 [==============================] - 16s 24ms/step - loss: 357.5472 - val_loss: 343.0978
# Epoch 2/15
# 600/600 [==============================] - 14s 23ms/step - loss: 306.2887 - val_loss: 305.3723
# Epoch 3/15
# 600/600 [==============================] - 14s 23ms/step - loss: 304.4969 - val_loss: 306.6245
# Epoch 4/15
# 600/600 [==============================] - 14s 23ms/step - loss: 303.4992 - val_loss: 303.4806
# Epoch 5/15
# 600/600 [==============================] - 14s 23ms/step - loss: 302.3868 - val_loss: 304.3123
# Epoch 6/15
# 600/600 [==============================] - 14s 23ms/step - loss: 301.7827 - val_loss: 309.9405
# Epoch 7/15
# 600/600 [==============================] - 14s 23ms/step - loss: 301.6371 - val_loss: 302.0215
# Epoch 8/15
# 600/600 [==============================] - 14s 23ms/step - loss: 301.1072 - val_loss: 304.7664
# Epoch 9/15
# 600/600 [==============================] - 14s 23ms/step - loss: 300.9081 - val_loss: 301.6102
# Epoch 10/15
# 600/600 [==============================] - 14s 23ms/step - loss: 300.4798 - val_loss: 301.9594
# Epoch 11/15
# 600/600 [==============================] - 14s 23ms/step - loss: 300.7147 - val_loss: 301.1927
# Epoch 12/15
# 600/600 [==============================] - 14s 23ms/step - loss: 300.2200 - val_loss: 301.9231
# Epoch 13/15
# 600/600 [==============================] - 14s 23ms/step - loss: 299.7090 - val_loss: 301.3531
# Epoch 14/15
# 600/600 [==============================] - 14s 23ms/step - loss: 299.4061 - val_loss: 301.5486
# Epoch 15/15
# 600/600 [==============================] - 14s 23ms/step - loss: 300.2905 - val_loss: 301.6536

# %% [markdown]
# Image generation after training

# %%
generated = cdecoder.predict(np.random.normal(size=(1, latent_dim)))
plt.imshow(generated.reshape(28, 28), cmap=plt.cm.gray)
plt.axis('off');

# %% [markdown]
# Comparison test set / MLP-based VAE / CNN-based VAE

# %%
x_test_decoded_cvae = cvae.predict(x_test_CNN, batch_size= 100)
x_test_decoded_vae = vae.predict(x_test_MLP, batch_size= 100)

n = 10 
plt.figure(figsize=(15, 6))
for i in range(n):
    ax = plt.subplot(3, n, i + 1)
    plt.title('Test Images')
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    ax = plt.subplot(3, n, i + 1 + n)
    plt.title('CVAE')
    plt.imshow(x_test_decoded_cvae[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(3, n, i + 1 + 2*n)
    plt.title('VAE')
    plt.imshow(x_test_decoded_vae[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.tight_layout()

# %% [markdown]
# ### 2D projection

# %%
x_test_encoded, _ = cencoder.predict(x_test_CNN, batch_size=100)
plt.figure(figsize=(10, 6))
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test,cmap=plt.cm.tab10)
cb = plt.colorbar()
cb.set_ticks(list(labels.keys()))
cb.set_ticklabels(list(labels.values()))
cb.update_ticks()
plt.tight_layout()

# %%
n = 20  
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
grid_x = norm.ppf(np.linspace(0.05, 0.95, n))
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = cdecoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.tight_layout()
